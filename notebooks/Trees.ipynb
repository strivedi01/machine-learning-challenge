# %%
from sklearn import tree
import pandas as pd
import os

# %%
# read in the data

df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %%
# define target

target = df["koi_disposition"]
target_names = ["FALSE POSITIVE", "CONFIRMED","CANDIDATE"]

# %%
# define features

data = df.drop("koi_disposition", axis=1)
feature_names = data.columns
data.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1     1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3     3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4     1.050000e-05    -1.050000e-05   172.979370          0.001900
#
#    koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %%
# define train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
# DecisionTreeClassifier

clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.8478260869565217

# %%
# RandomForestClassifier

from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.8975972540045767

# %%
# FeatureImportance

sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.10435098884504784, 'koi_fpflag_co'),
#  (0.09355991136548089, 'koi_fpflag_nt'),
#  (0.06559800539126552, 'koi_fpflag_ss'),
#  (0.05211290395856137, 'koi_prad'),
#  (0.05142393885917214, 'koi_model_snr'),
#  (0.036572682190295615, 'koi_duration_err2'),
#  (0.03404567145972788, 'koi_fpflag_ec'),
#  (0.03401228710609116, 'koi_duration_err1'),
#  (0.033863201167665155, 'koi_prad_err1'),
#  (0.03221252876281922, 'koi_steff_err1'),
#  (0.03157313463372575, 'koi_steff_err2'),
#  (0.02866847341977579, 'koi_prad_err2'),
#  (0.02536016725409224, 'koi_period'),
#  (0.024144869973227127, 'koi_time0bk_err1'),
#  (0.02326040088173245, 'koi_duration'),
#  (0.0230746247338073, 'koi_time0bk_err2'),
#  (0.0213404288222891, 'koi_depth'),
#  (0.018538480822522862, 'koi_insol_err1'),
#  (0.018019161741410578, 'koi_period_err2'),
#  (0.017789583258602353, 'koi_period_err1'),
#  (0.016977097810709694, 'koi_impact'),
#  (0.016809291219533576, 'koi_insol'),
#  (0.01646625060086622, 'koi_teq'),
# ...

# %%
import joblib
#filepath= '../saved_models'
filename = '../saved_models/ST_RandomForest.sav'
joblib.dump(rf, filename)
# Out:
# ['../saved_models/ST_RandomForest.sav']

# %%
filename = '../saved_models/ST_DecisionTreeClassifier.sav'
joblib.dump(clf, filename)
# Out:
# ['../saved_models/ST_DecisionTreeClassifier.sav']

# %% [markdown]
# # Conclusion

# %% [raw]
# Neural Networks model and Deep Learning model scores are ver close.
# Neural Network model: 0.868993163108825 Deep Learning model: 0.881578922271728
#
# Random Forest model's best score of (0.897597254004576) is better than
# Logistic Regression model (0.862128146453089).
#
# Random Forest model saved as best model.
